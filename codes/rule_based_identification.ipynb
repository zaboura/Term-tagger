# %%
import os
import pandas as pd

# %%
f = pd.read_csv('../astronomy - Sheet.csv')

# %%
terms = list(f['key'].values)
# terms

# %%
import spacy
from spacy.matcher import PhraseMatcher

# %%
nlp = spacy.load('en_core_web_sm')
matched_sents = []  # Collect data of matched sentences to be visualized

def collect_sents(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start:end]  # Matched span
    sent = span.sent  # Sentence containing matched span
    # Append mock entity for match in displaCy style to matched_sents
    # get the match span by ofsetting the start and end of the span with the
    # start and end of the sentence in the doc
    match_ents = [{
        "start": span.start_char - sent.start_char,
        "end": span.end_char - sent.start_char,
        "label": "AstroTerm",
    }]
    matched_sents.append({"text": sent.text, "ents": match_ents})

matcher = PhraseMatcher(nlp.vocab)

# %%
patterns = [nlp.make_doc(text) for text in terms]
patterns
matcher.add("TerminologyList", collect_sents, *patterns)

# %%
text = open("../corpus/Astromony_04.txt", encoding='utf-8')
text = text.read()

# %%
doc = nlp(text)
matches = matcher(doc)
for match_id, start, end in matches:
    span = doc[start:end]
#     print(span.text)

# %%
from spacy import displacy
displacy.render(matched_sents, style="ent", manual=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As usual, we've been deprived of clear sky viewing opportunities this winter and spring—all the more reason to start planning for the regional
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dark sky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  star parties.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">As usual, we've been deprived of clear sky viewing opportunities this winter and spring—all the more reason to start planning for the regional dark sky
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     star
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  parties.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Also, you need to register early for this
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     star
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  party because attendance is limited: www.tmspa.com.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Also, you need to register early for this
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     star party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  because attendance is limited: www.tmspa.com.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The OSP always has a good speaker program, nightly sky tours, and a renowned
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     telescope
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  walkabout: www.oregonstarparty.org.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">If you can't attend regional
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     star
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  parties, the summer sky still offers plenty of good viewing.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">An article in the June 2010 Sky and Telescope (p. 40) describes the opportunities available, even in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     light
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  polluted areas, on June evenings.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Four first magnitude stars are visible near the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ecliptic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
# , Antares, Spica, Regulus, and Pollux, plus three bright planets, Venus, Mars, and Saturn, along with the bright stars of the Summer Triangle, Vega, Deneb and Altair, and in the west, Arcturus.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Another bonus in June: Ceres, an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     asteroid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  large enough to achieve dwarf planet status, will be visible, reaching opposition on June 18 at magnitude 7.2.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Another bonus in June: Ceres, an asteroid large enough to achieve dwarf
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     planet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  status, will be visible, reaching opposition on June 18 at magnitude 7.2.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">And on June 26 all but the final stages of a partial
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lunar eclipse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  will be visible from the western U.S., just before dawn.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">And on June 26 all but the final stages of a partial lunar
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eclipse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  will be visible from the western U.S., just before dawn.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The Perseids
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     meteor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  shower peaks August twelfth.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The Perseids are reliable, better of course from a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dark sky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  site like the Oregon Star Party, but visible from local venues as well.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The monthly
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     planetarium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AstroTerm</span>
# </mark>
#  shows will continue through the summer, and if the weather cooperates, be paired with star parties.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
